# %% [markdown]
# # Osnutek reporta

# %% [markdown]
# #  Filtriranje podatkov, procesiranje
#
#
# Deleži manjkajočih, pomankljivih atributov:
#     Koordinate 2.67%
#     Starost  0.04%
#     Brez izpita 25.32%%
# Koordinate, Starost -> vrednosti s  so bile odstranjene, saj je delež zelo majhen.
#
# Vozniški staž je podan kot dva ločena atributa, v letih in v mesecih, zato ju je bilo potrebno ustrezno kombinirati v nov bolj uporaben atribut.
#
# Ura nesreče je shranjena kot niz, za pretvorbo smo vzeli samo uro, saj točen čas ni bistvenega pomena za naše analize.
#
#
# # Razmere ob katerih največkrat pride do prometnih nesreč
#
#
#
# # Profil voznika povzročiteljev prometnih nesreč
#
#
#
# # Pogoste pojavitve prometnih nesreč po posameznih krajih in mesecih
# ## Prometne nesreče glede na mesec
# <table><tr>
#     <td> <img src="./grafi/plot_%hudih_nes.png" alt="Alt text that describes the graphic" title="Title text" width="300"/> </td>
#     <td> <img src="./grafi/plot_st_nesrec_skozi_mesece.png" alt="Alt text that describes the graphic" title="Title text" width="300"/></td>
#     </tr></table>
# iz grafov opazimo da pride do največ hudih nesreč ali nesreč z smrtnim izidom med pomladjo in poletjem. Medtem ko do največ nesreč pride okrog meseca oktobra.
#
# ## Glede na upravno enoto
# glede na mesec v letu so nasednje upravne enote imele največji procent hudih nesereč:\
# jan:LITIJA ,feb:DRAVOGRAD, mar:MOZIRJE, apr:VRHNIKA, maj:TRŽIč, jun:HRASTNIK, jul:MOZIRJE, avg:ILIRSKA BISTRICA,
# sep:ILIRSKA BISTRICA, oct:ZAGORJE OB SAVI, nov:GORNJA RADGONA, dec:ILIRSKA BISTRICA\
# Izmed teh se je ILIRSKA BISTRICA pojavila kar 3-krat in MOZIRJE 2-krat.\
# Ljubljana pa je zaradi velikosti in gostote prometa imela največ prometnih nesreč skozi vse mesece.
#
#
# ## Glede na regijo
# zasavska regije je imela največji delež hudih nesreč v mesecu glede na število nesreč v regiji kar 5-kart, takoj za njo primorsko-notranska ,ki se je pojavila 4-krat. ostale 3 mesece pa so imele največji delež gorenskja, goriška in koroška.
#
#
# # Relacije med okoliščinami prometne nesreče in stopnjo poškodb udeležencev
#
# # Alkohol v prometnih nesrečah
# ## Povzročitelji proti udeležencem
# <img src="./grafi/graf_vinjeni_nevinjeni_glede_na_spol.png" alt="Alt text that describes the graphic" title="Title text" width="300"/>
# Iz grafa opazimo da je veliko večji delež vinjenih voznikov povzročiteljev kot pa udeležencev  v prometnih nesrečah\
#
# ## Povezava z spolom
# povprečna vrednost alkohola v izdihanem zraku pri ženskah je 0.012 pri moških pa 0.040
# ## Povezava z uro v dnevu
# <img src="./grafi/scater_ura_alko.png" alt="Alt text that describes the graphic" title="Title text" width="300"/>
# Opazili smo da pride do največ nesreč z vinjenimi udeleženci, ki zakonsko presegajo dovoljeno mejo zaužitega lakohola med 3.uro in 9.uro popoldan
# <img src="./grafi/pov_alko_ura.png" alt="Alt text that describes the graphic" title="Title text" width="300"/>
# medtem ko je največja povprečna raven alkohola v krvi me polnočjo in 5.uro zjutraj
#
# ## Povezava z starostjo
#
# <img src="./grafi/starost_alko.png" alt="Alt text that describes the graphic" title="Title text" width="300"/>
# iz grafa je razvidno je raven alkohola pri nesrečah v krvi največja med 18 in 25 letom starosti na kar drastično pade ter se začne ponovno vzpenjati vse do 60 leta starosti
#
# ## povezava z resnostjo nesreče
# Podatke smo razdelili v 5 kategorij na podlagi mg/l izdihanega lakohola:\
# 1. 0-0.1(mg/l):
# ni učinka
# 2. 0.1-0.14(mg/l):
# Poslabša se sposobnost opazovanja premikajočih se luči
# 3. 0.14-0.24(mg/l):
# Poslabša se sposobnost globinskega opazovanja in s tem pravilne
# izbire varnostne razdalje. Zmanjša se kritičnost do lastnega ravnanja in
# samokontrola. Poveča se pripravljenost za tveganje, lahko tudi
# agresivnost.
# 4. 0.24-0.38(mg/l):
# Pojavi se rdeča slepota (slabša zaznava rdeče luči na semaforju in
# zavornih luči),
# Zmanjšuje se sposobnost hitrega preusmerjanja pogleda z enega
# predmeta na drugega,
# Pridobi se občutek, da so predmeti bolj oddaljeni, kot so v resnici,
# Podaljša se reakcijski čas,
# Pojavijo se motnje ravnotežja,
# Pojavijo se napačne ocene hitrosti vozil,
# Voznik se vedno težje prilagaja naglim svetlobnim spremembam.
# Večina ljudi pri doseženi stopnji 0,5 g/kg ne zmore odločitve, da ne bo
# popila ničesar več.
# 5. več od 0.38(mg/l):
# Bistveno se poslabša možnost koncentracije
# Do 25% se zmanjša ostrina vida
# Pojavi se oženje vidnega polja in t. i. tunelski vid,
# Reakcijski čas se podaljša za 35-50%,
# Pojavi se stanje evforije
# Voznik se ne kontrolira več in precenjuje svoje sposobnosti
# Bistveno se poslabšajo zmožnosti prostorske zaznave in ocene
# oddaljenosti vozil in predmetov, ki se približujejo
# Voznik ne more več usmerjati pogleda\
#
# in dobili nasledje rezutate:
# 1. procent hudih poškodb pri:
# - 0-0.1(mg/l): 0.040
# - 0.1-0.14(mg/l): 0.085
# - 0.14-0.24(mg/l): 0.084
# - 0.24-0.38(mg/l): 0.032
# - 0.38-8(mg/l): 0.052
# 2. procent lahkih poškodb pri:
# - 0-0.1: 0.31125827814569534
# - 0.1-0.14: 0.35714285714285715
# - 0.14-0.24: 0.36363636363636365
# - 0.24-0.38: 0.27102803738317754
# - 0.38-8: 0.30286168521462636
#
# še bolj zanimiva je bila ugotovitev da se z ravnijo alkohola v krvi veča verjetnost da boš utrpev hudo telesno poškodbo kot udeleženec medtem ko so verjetnost da boš utrpev hudo telesno poškodbo kot povzročitel manjša
# <table><tr>
#     <td> <img src="./grafi/proc_povz_alko_nes.png" alt="Alt text that describes the graphic" title="Title text" width="300"/> </td>
#     <td> <img src="./grafi/proc_ude_alko_nes.png" alt="Alt text that describes the graphic" title="Title text" width="300"/></td>
#     </tr></table>
